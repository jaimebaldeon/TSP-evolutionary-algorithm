# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimebaldeon/TSP-evolutionary-algorithm/blob/main/TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Only needed to import the file into colab, needs only to be run once
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-34059147-edc3-4753-8f6e-c622f55d41a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34059147-edc3-4753-8f6e-c622f55d41a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tour29.csv to tour29.csv

# %%
filename = next(iter(towns_csv))
matrix = genfromtxt(filename,delimiter=',')
matrix

# %%
import numpy as np
import statistics
import random

class TSP:
  def __init__(self, numVertices):
    #self.vertices = [n for n in range(1, numVertices+1)] #to accomplish natural values for vertices
    self.vertices = [n for n in range(numVertices)]
    matrix = np.random.randint(100, 500, size=(numVertices, numVertices))
    np.fill_diagonal(matrix, 0)
    self.distanceMatrix = matrix

class Individual:
  def __init__(self, tsp):
    self.order = np.random.permutation(tsp.vertices)
    self.α = 0.05

def fitness(tsp, ind):
  value = 0
  ii = 0
  for i in ind.order:
    # Sum up total distance for the individual's sequence of nodes 
    while (ii < ind.order.size - 1):
      pairVertices = ind.order[ii:ii+2]
      value += tsp.distanceMatrix[pairVertices[0], pairVertices[1]]
      ii += 1 
  # add the distance between first and last node
  value += tsp.distanceMatrix[ind.order[-1], ind.order[0]]
  return value

def optimize(tsp):
  λ = 100 # population size
  μ = 100 # offspring size
  iter =100

  # Initialization
  population = initialize(tsp,λ)
  offspring = []

  # Print initial Candidate solutions
  for ind in population:
    print("Candidate solution:  ", ind.order)

  # Print initial Population evaluation
  fitnesses = [fitness(tsp, ind) for ind in population]
  print("\nMean fitness:  ", statistics.mean(fitnesses))
  print("Best fitness:  ", min(fitnesses))

  for i in range(iter):
    # Recombination
    for ind in range(μ):
      # Selection
      parent1 = selection(tsp, population)
      parent2 = selection(tsp, population)
      offspring.append(recombination(parent1, parent2))
      mutate(offspring[ind])

    # Mutation
    for ind in population:
      mutate(ind)    

    # Elimination
    population = elimination(population, offspring, tsp)

    fitnesses = [fitness(tsp, ind) for ind in population]
    print(f'---------------------------------  ITERATION {i} ---------------------------------')
    print("Mean fitness:  ", statistics.mean(fitnesses))
    print("Best fitness:  ", min(fitnesses))

  # Print final Candidate solutions
  for ind in population:
    print("Candidate solution:  ", ind.order)
    print("Candidate mutation probability:  ", ind.α)


def initialize(tsp, λ):
  population = []
  for i in range(λ):
    population.append(Individual(tsp))
  return population

def mutate(individual):
  if np.random.rand() < individual.α:
    i = random.randrange(len(individual.order))
    j = random.randrange(len(individual.order))
    if i < j:
      individual.order[i:j] = individual.order[i:j][::-1]
    else:
      individual.order[j:i] = individual.order[j:i][::-1]

def recombination(parent1, parent2):
  child = parent1
  # Select crossover points randomly
  i = random.randrange(len(parent1.order))
  j = random.randrange(len(parent1.order))
  # Perform order crossover recombination to create the child's order
  if i < j:  
    child.order = order_crossover(parent1.order, parent2.order, i, j)
  else:  
    child.order = order_crossover(parent1.order, parent2.order, j, i)  
  # Set child parameters
  β = 2 * np.random.rand() - 0.5 # coefficient between (-0.5, 1.5)
  child.α = parent1.α + β * (parent2.α - parent1.α)
  return child

def order_crossover(parent1, parent2, i,j):
  # Create loop effect over array
  p1 = np.concatenate((parent1, parent1), axis=None)
  p2 = np.concatenate((parent2, parent2), axis=None)
  # Create empty child order
  child = np.full(len(parent2), None) 
  # Fill child with random selected sequence from parent1
  child[i:j] = p1[i:j]
  # Set pointers to the second crossover point in parent2 (jj) and child (ii)
  ii, jj = j, j
  # The recombination stops when all nodes in parent2 sequence have been added to the child
  while (jj < j + len(parent2)):
    if ii > len(parent2)-1:
      # when child's pointer reaches the end of the array go to position 0
      ii = 0
    if p2[jj] not in child: 
      # Missing nodes are added to the child
      child[ii] = p2[jj]
      ii += 1 # when added a new node, shift child's pointer to the left
    jj += 1
  return child

def selection(tsp, population):
  k = 5
  candidates = random.sample(population, k)
  fitnesses = [fitness(tsp, ind) for ind in candidates]
  selected = fitnesses.index(min(fitnesses))
  return candidates[selected]

def elimination(population, offspring, tsp):
  # λ+μ elimination
  combined = population + offspring
  ranked_individuals = sorted([(fitness(tsp, ind), ind) for ind in combined], key=lambda ind: ind[0])[0:len(population)]
  return [ind for fit, ind in ranked_individuals]

# %%
tsp = TSP(5)
population=initialize(tsp,15)
for i in population:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

parent1 = selection(tsp, population)
parent2 = selection(tsp, population)
print(f'\n Selected parent {parent1.order} y fitness: {fitness(tsp, parent1)}')
print(f'\n Selected parent {parent2.order} y fitness: {fitness(tsp, parent2)}')

offspring = recombination(parent1, parent2)
print(f'\n Offspring recombination {offspring.order} y fitness: {fitness(tsp, offspring)}')

mutate(offspring)
print(f'\n Offspring mutated {offspring.order} y fitness: {fitness(tsp, offspring)}')

# Mutation
for ind in population:
  mutate(ind)    

off = [offspring]
# Elimination
population = elimination(population, off, tsp)
for i in population:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

# %%
tsp = TSP(5)

#print("Vertices:  ", tsp.vertices)
print(type(tsp.distanceMatrix))
print("Distance:  \n", tsp.distanceMatrix)

optimize(tsp)

"""best = elimination(pop, pop, tsp)
for i in best:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

fitnesses = [fitness(tsp, ind) for ind in best]
print("\nMean fitness:  ", statistics.mean(fitnesses))
print("Best fitness:  ", min(fitnesses))
"""
# Out:
# <class 'numpy.ndarray'>
# Distance:
#  [[  0 333 355 142 147]
#  [372   0 493 303 375]
#  [291 476   0 250 180]
#  [132 227 216   0 162]
#  [416 124 298 164   0]]
# Candidate solution:   [3 1 0 2 4]
# Candidate solution:   [0 2 3 4 1]
# Candidate solution:   [1 4 2 3 0]
# Candidate solution:   [0 3 2 4 1]
# Candidate solution:   [1 0 3 2 4]
# Candidate solution:   [4 0 1 3 2]
# Candidate solution:   [3 1 4 0 2]
# Candidate solution:   [3 1 4 2 0]
# Candidate solution:   [3 0 1 4 2]
# Candidate solution:   [0 3 1 2 4]
# Candidate solution:   [0 1 4 2 3]
# Candidate solution:   [4 3 0 2 1]
# Candidate solution:   [3 2 1 4 0]
# Candidate solution:   [2 1 4 3 0]
# Candidate solution:   [0 3 4 2 1]
# Candidate solution:   [1 2 0 4 3]
# Candidate solution:   [2 3 0 1 4]
# Candidate solution:   [1 3 2 0 4]
# Candidate solution:   [3 0 2 1 4]
# Candidate solution:   [4 0 1 2 3]
# Candidate solution:   [1 4 3 0 2]
# Candidate solution:   [1 4 3 0 2]
# Candidate solution:   [4 1 3 2 0]
# Candidate solution:   [3 2 1 0 4]
# Candidate solution:   [2 1 3 0 4]
# Candidate solution:   [1 3 4 2 0]
# Candidate solution:   [0 4 1 3 2]
# Candidate solution:   [0 1 4 2 3]
# Candidate solution:   [2 1 4 3 0]
# Candidate solution:   [2 3 0 4 1]
# Candidate solution:   [4 3 1 0 2]
# Candidate solution:   [0 4 3 2 1]
# Candidate solution:   [3 0 1 4 2]
# Candidate solution:   [4 1 0 3 2]
# Candidate solution:   [0 2 1 4 3]
# Candidate solution:   [1 0 3 2 4]
# Candidate solution:   [4 3 2 0 1]
# Candidate solution:   [3 4 0 2 1]
# Candidate solution:   [0 2 3 4 1]
# Candidate solution:   [4 1 3 2 0]
# Candidate solution:   [4 1 2 0 3]
# Candidate solution:   [3 4 0 2 1]
# Candidate solution:   [3 4 0 1 2]
# Candidate solution:   [1 0 3 2 4]
# Candidate solution:   [4 3 2 1 0]
# Candidate solution:   [3 1 2 0 4]
# Candidate solution:   [1 3 4 2 0]
# Candidate solution:   [1 0 3 2 4]
# Candidate solution:   [0 3 2 4 1]
# Candidate solution:   [4 3 0 1 2]
# Candidate solution:   [0 3 1 2 4]
# Candidate solution:   [0 1 2 3 4]
# Candidate solution:   [1 2 4 3 0]
# Candidate solution:   [3 2 4 1 0]
# Candidate solution:   [1 3 0 2 4]
# Candidate solution:   [4 0 3 1 2]
# Candidate solution:   [0 2 4 1 3]
# Candidate solution:   [2 3 4 0 1]
# Candidate solution:   [0 1 2 3 4]
# Candidate solution:   [3 0 2 4 1]
# Candidate solution:   [0 3 1 4 2]
# Candidate solution:   [1 4 0 3 2]
# Candidate solution:   [4 0 3 2 1]
# Candidate solution:   [1 3 2 4 0]
# Candidate solution:   [4 1 0 3 2]
# Candidate solution:   [1 0 4 2 3]
# Candidate solution:   [1 4 3 2 0]
# Candidate solution:   [3 1 4 0 2]
# Candidate solution:   [1 3 0 2 4]
# Candidate solution:   [4 1 0 2 3]
# Candidate solution:   [3 1 0 2 4]
# Candidate solution:   [0 1 2 3 4]
# Candidate solution:   [4 0 2 3 1]
# Candidate solution:   [4 1 0 2 3]
# Candidate solution:   [2 1 0 4 3]
# Candidate solution:   [4 2 3 0 1]
# Candidate solution:   [4 3 2 1 0]
# Candidate solution:   [3 4 2 1 0]
# Candidate solution:   [1 0 3 4 2]
# Candidate solution:   [0 3 2 1 4]
# Candidate solution:   [0 1 2 3 4]
# Candidate solution:   [3 2 0 1 4]
# Candidate solution:   [1 0 2 3 4]
# Candidate solution:   [2 0 1 3 4]
# Candidate solution:   [1 0 2 3 4]
# Candidate solution:   [0 2 3 1 4]
# Candidate solution:   [0 2 4 1 3]
# Candidate solution:   [0 3 4 1 2]
# Candidate solution:   [1 4 2 0 3]
# Candidate solution:   [4 1 2 3 0]
# Candidate solution:   [4 2 1 3 0]
# Candidate solution:   [1 2 3 4 0]
# Candidate solution:   [3 1 0 2 4]
# Candidate solution:   [1 4 2 3 0]
# Candidate solution:   [4 0 1 3 2]
# Candidate solution:   [3 4 1 0 2]
# Candidate solution:   [2 4 1 3 0]
# Candidate solution:   [2 3 4 1 0]
# Candidate solution:   [1 0 2 4 3]
# Candidate solution:   [1 2 4 0 3]
#
# Mean fitness:   1357
# Best fitness:   1034
# ---------------------------------  ITERATION 0 ---------------------------------
# Mean fitness:   1275
# Best fitness:   1034
# ---------------------------------  ITERATION 1 ---------------------------------
# Mean fitness:   1286
# Best fitness:   1146
# ---------------------------------  ITERATION 2 ---------------------------------
# Mean fitness:   1137
# Best fitness:   1034
# ---------------------------------  ITERATION 3 ---------------------------------
# Mean fitness:   1290
# Best fitness:   1263
# ---------------------------------  ITERATION 4 ---------------------------------
# Mean fitness:   1304
# Best fitness:   1294
# ---------------------------------  ITERATION 5 ---------------------------------
# Mean fitness:   1105
# Best fitness:   1081
# ---------------------------------  ITERATION 6 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 7 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1212
# ---------------------------------  ITERATION 8 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1212
# ---------------------------------  ITERATION 9 ---------------------------------
# Mean fitness:   1333
# Best fitness:   1333
# ---------------------------------  ITERATION 10 ---------------------------------
# Mean fitness:   1207
# Best fitness:   1034
# ---------------------------------  ITERATION 11 ---------------------------------
# Mean fitness:   1322
# Best fitness:   1322
# ---------------------------------  ITERATION 12 ---------------------------------
# Mean fitness:   1360
# Best fitness:   1263
# ---------------------------------  ITERATION 13 ---------------------------------
# Mean fitness:   1258
# Best fitness:   1034
# ---------------------------------  ITERATION 14 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 15 ---------------------------------
# Mean fitness:   1276
# Best fitness:   1081
# ---------------------------------  ITERATION 16 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 17 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 18 ---------------------------------
# Mean fitness:   1298
# Best fitness:   1298
# ---------------------------------  ITERATION 19 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 20 ---------------------------------
# Mean fitness:   1333
# Best fitness:   1081
# ---------------------------------  ITERATION 21 ---------------------------------
# Mean fitness:   1139
# Best fitness:   1081
# ---------------------------------  ITERATION 22 ---------------------------------
# Mean fitness:   1094
# Best fitness:   1094
# ---------------------------------  ITERATION 23 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1212
# ---------------------------------  ITERATION 24 ---------------------------------
# Mean fitness:   1301
# Best fitness:   1294
# ---------------------------------  ITERATION 25 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 26 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 27 ---------------------------------
# Mean fitness:   1243
# Best fitness:   1034
# ---------------------------------  ITERATION 28 ---------------------------------
# Mean fitness:   1204
# Best fitness:   1146
# ---------------------------------  ITERATION 29 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 30 ---------------------------------
# Mean fitness:   1094
# Best fitness:   1094
# ---------------------------------  ITERATION 31 ---------------------------------
# Mean fitness:   1329
# Best fitness:   1263
# ---------------------------------  ITERATION 32 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 33 ---------------------------------
# Mean fitness:   1154
# Best fitness:   1094
# ---------------------------------  ITERATION 34 ---------------------------------
# Mean fitness:   1094
# Best fitness:   1094
# ---------------------------------  ITERATION 35 ---------------------------------
# Mean fitness:   1094
# Best fitness:   1094
# ---------------------------------  ITERATION 36 ---------------------------------
# Mean fitness:   1342
# Best fitness:   1212
# ---------------------------------  ITERATION 37 ---------------------------------
# Mean fitness:   1164
# Best fitness:   1094
# ---------------------------------  ITERATION 38 ---------------------------------
# Mean fitness:   1289
# Best fitness:   1212
# ---------------------------------  ITERATION 39 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 40 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 41 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1212
# ---------------------------------  ITERATION 42 ---------------------------------
# Mean fitness:   1259
# Best fitness:   1146
# ---------------------------------  ITERATION 43 ---------------------------------
# Mean fitness:   1298
# Best fitness:   1298
# ---------------------------------  ITERATION 44 ---------------------------------
# Mean fitness:   1302
# Best fitness:   1302
# ---------------------------------  ITERATION 45 ---------------------------------
# Mean fitness:   1285
# Best fitness:   1094
# ---------------------------------  ITERATION 46 ---------------------------------
# Mean fitness:   1375
# Best fitness:   1356
# ---------------------------------  ITERATION 47 ---------------------------------
# Mean fitness:   1196
# Best fitness:   1081
# ---------------------------------  ITERATION 48 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 49 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 50 ---------------------------------
# Mean fitness:   1292
# Best fitness:   1263
# ---------------------------------  ITERATION 51 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 52 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1212
# ---------------------------------  ITERATION 53 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 54 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 55 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 56 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1212
# ---------------------------------  ITERATION 57 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 58 ---------------------------------
# Mean fitness:   1271
# Best fitness:   1146
# ---------------------------------  ITERATION 59 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 60 ---------------------------------
# Mean fitness:   1310
# Best fitness:   1294
# ---------------------------------  ITERATION 61 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 62 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 63 ---------------------------------
# Mean fitness:   1190
# Best fitness:   1094
# ---------------------------------  ITERATION 64 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1081
# ---------------------------------  ITERATION 65 ---------------------------------
# Mean fitness:   1193
# Best fitness:   1081
# ---------------------------------  ITERATION 66 ---------------------------------
# Mean fitness:   1279
# Best fitness:   1263
# ---------------------------------  ITERATION 67 ---------------------------------
# Mean fitness:   1156
# Best fitness:   1094
# ---------------------------------  ITERATION 68 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1212
# ---------------------------------  ITERATION 69 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 70 ---------------------------------
# Mean fitness:   1208
# Best fitness:   1081
# ---------------------------------  ITERATION 71 ---------------------------------
# Mean fitness:   1196
# Best fitness:   1081
# ---------------------------------  ITERATION 72 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 73 ---------------------------------
# Mean fitness:   1302
# Best fitness:   1302
# ---------------------------------  ITERATION 74 ---------------------------------
# Mean fitness:   1325
# Best fitness:   1212
# ---------------------------------  ITERATION 75 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 76 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 77 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 78 ---------------------------------
# Mean fitness:   1212
# Best fitness:   1212
# ---------------------------------  ITERATION 79 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 80 ---------------------------------
# Mean fitness:   1146
# Best fitness:   1146
# ---------------------------------  ITERATION 81 ---------------------------------
# Mean fitness:   1094
# Best fitness:   1094
# ---------------------------------  ITERATION 82 ---------------------------------
# Mean fitness:   1081
# Best fitness:   1081
# ---------------------------------  ITERATION 83 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 84 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 85 ---------------------------------
# Mean fitness:   1298
# Best fitness:   1298
# ---------------------------------  ITERATION 86 ---------------------------------
# Mean fitness:   1294
# Best fitness:   1294
# ---------------------------------  ITERATION 87 ---------------------------------
# Mean fitness:   1263
# Best fitness:   1263
# ---------------------------------  ITERATION 88 ---------------------------------
# Mean fitness:   1254
# Best fitness:   1212
# ---------------------------------  ITERATION 89 ---------------------------------
# Mean fitness:   1094
# Best fitness:   1094
# ---------------------------------  ITERATION 90 ---------------------------------
# Mean fitness:   1250
# Best fitness:   1212
# ---------------------------------  ITERATION 91 ---------------------------------
# Mean fitness:   1298
# Best fitness:   1298
# ---------------------------------  ITERATION 92 ---------------------------------
# Mean fitness:   1034
# Best fitness:   1034
# ---------------------------------  ITERATION 93 ---------------------------------
# Mean fitness:   1302
# Best fitness:   1302
# ---------------------------------  ITERATION 94 ---------------------------------
# Mean fitness:   1253
# Best fitness:   1034
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-3274f630aa55> in <module>()
#       5 print("Distance:  \n", tsp.distanceMatrix)
#       6
# ----> 7 optimize(tsp)
#       8
#       9 """best = elimination(pop, pop, tsp)
#
# <ipython-input-65-f0d3e626f9b8> in optimize(tsp)
#      61
#      62     # Elimination
# ---> 63     population = elimination(population, offspring, tsp)
#      64
#      65     fitnesses = [fitness(tsp, ind) for ind in population]
#
# <ipython-input-65-f0d3e626f9b8> in elimination(population, offspring, tsp)
#     136   # λ+μ elimination
#     137   combined = population + offspring
# --> 138   ranked_individuals = sorted([(fitness(tsp, ind), ind) for ind in combined], key=lambda ind: ind[0])[0:len(population)]
#     139   return [ind for fit, ind in ranked_individuals]
#
# <ipython-input-65-f0d3e626f9b8> in <listcomp>(.0)
#     136   # λ+μ elimination
#     137   combined = population + offspring
# --> 138   ranked_individuals = sorted([(fitness(tsp, ind), ind) for ind in combined], key=lambda ind: ind[0])[0:len(population)]
#     139   return [ind for fit, ind in ranked_individuals]
#
# <ipython-input-65-f0d3e626f9b8> in fitness(tsp, ind)
#      22     # Sum up total distance for the individual's sequence of nodes
#      23     while (ii < ind.order.size - 1):
# ---> 24       pairVertices = ind.order[ii:ii+2]
#      25       value += tsp.distanceMatrix[pairVertices[0], pairVertices[1]]
#      26       ii += 1
#
# KeyboardInterrupt:
