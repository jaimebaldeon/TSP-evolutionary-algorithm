# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimebaldeon/TSP-evolutionary-algorithm/blob/main/TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statistics
import random

class TSP:
  def __init__(self, matrix):
    #self.vertices = [n for n in range(1, numVertices+1)] #to accomplish natural values for vertices
    self.vertices = [n for n in range(matrix[0].size)]  # vertices from 0 to N
    if np.max(matrix) == inf:
      # infinite weights must be changed to finite values
      self.distanceMatrix = np.where(matrix==inf,1e8, matrix)
    else:
      self.distanceMatrix = matrix

class Individual:
  def __init__(self, tsp):
    self.order = np.random.permutation(tsp.vertices)
    self.α = 0.05

def fitness(tsp, ind):
  value = 0
  ii = 0
  for i in ind.order:
    # Sum up total distance for the individual's sequence of nodes 
    while (ii < ind.order.size - 1):
      pairVertices = ind.order[ii:ii+2]
      value += tsp.distanceMatrix[pairVertices[0], pairVertices[1]]
      ii += 1 
  # add the distance between first and last node
  value += tsp.distanceMatrix[ind.order[-1], ind.order[0]]
  return value

def optimize(tsp):
  λ = 3000 # population size
  μ = 3000 # offspring size
  iter =100

  # Initialization
  population = initialize(tsp,λ)
  offspring = []

  # Print initial Candidate solutions
  '''for ind in population:
    print("Candidate solution:  ", ind.order)'''

  # Print initial Population evaluation
  fitnesses = [fitness(tsp, ind) for ind in population]
  print("\nMean fitness:  ", statistics.mean(fitnesses))
  print("Best fitness:  ", min(fitnesses))

  for i in range(iter):
    # Recombination
    for ind in range(μ):
      # Selection
      parent1 = selection(tsp, population)
      parent2 = selection(tsp, population)
      offspring.append(recombination(parent1, parent2, tsp))
      mutate(offspring[ind])

    # Mutation
    for ind in population:
      mutate(ind)    

    # Elimination
    population = elimination(population, offspring, tsp)

    fitnesses = [fitness(tsp, ind) for ind in population]
    print(f'---------------------------------  ITERATION {i} ---------------------------------')
    print("Mean fitness:  ", statistics.mean(fitnesses))
    print("Best fitness:  ", min(fitnesses))

  # Print Best final Candidate solution
  bestSol = fitnesses.index(min(fitnesses))
  print(population[bestSol].order)
  # check if it has inf
  '''for ind in population:
    print("Candidate solution:  ", ind.order)
    print("Candidate mutation probability:  ", ind.α)'''


def initialize(tsp, λ):
  population = []
  for i in range(λ):
    population.append(Individual(tsp))
  return population

def mutate(individual):
  if np.random.rand() < individual.α:
    i = random.randrange(len(individual.order))
    j = random.randrange(len(individual.order))
    if i < j:
      individual.order[i:j] = individual.order[i:j][::-1]
    else:
      individual.order[j:i] = individual.order[j:i][::-1]

def recombination(parent1, parent2, tsp):
  child = Individual(tsp)
  # Select crossover points randomly
  i = random.randrange(len(parent1.order))
  j = random.randrange(len(parent1.order))
  # Perform order crossover recombination to create the child's order
  #print('ENTRO RECOMBINATION...')
  if i < j:  
    child.order = order_crossover(parent1.order, parent2.order, i, j)
    #print(f'CH: {child.order} F: {fitness(tsp, child)}')
    #print('FUNCTION: ' ,child.order)
  else:  
    child.order = order_crossover(parent1.order, parent2.order, j, i)
    #print(f'CH: {child.order} F: {fitness(tsp, child)}')
    #print('FUNCTION: ' ,child.order)
  # Set child parameters
  β = 2 * np.random.rand() - 0.5 # coefficient between (-0.5, 1.5)
  child.α = parent1.α + β * (parent2.α - parent1.α)
  #print(f'REAL CH: {child.order} F: {fitness(tsp, child)}')
  #print(f'P1: {parent1.order} F: {fitness(tsp, parent1)}\nP2: {parent2.order} F: {fitness(tsp, parent2)}\nCH: {child.order} F: {fitness(tsp, child)}')
  return child

def order_crossover(parent1, parent2, i,j):
  # Create loop effect over array
  p1 = np.concatenate((parent1, parent1), axis=None)
  p2 = np.concatenate((parent2, parent2), axis=None)
  # Create empty child order
  child = np.full(len(parent2), None) 
  # Fill child with random selected sequence from parent1
  child[i:j] = p1[i:j]
  # Set pointers to the second crossover point in parent2 (jj) and child (ii)
  ii, jj = j, j
  # The recombination stops when all nodes in parent2 sequence have been added to the child
  while (jj < j + len(parent2)):
    if ii > len(parent2)-1:
      # when child's pointer reaches the end of the array go to position 0
      ii = 0
    if p2[jj] not in child: 
      # Missing nodes are added to the child
      child[ii] = p2[jj]
      ii += 1 # when added a new node, shift child's pointer to the left
    jj += 1
  #print(f'P1: {parent1}\nP2: {parent2}\nCH: {child}')
  #print('RECOMBINATION: ' ,child)
  return child

def selection(tsp, population):
  k = 5
  candidates = random.sample(population, k)
  fitnesses = [fitness(tsp, ind) for ind in candidates]
  selected = fitnesses.index(min(fitnesses))
  return candidates[selected]

def elimination(population, offspring, tsp):
  # λ+μ elimination
  #print(sorted([(fitness(tsp, ind), ind) for ind in population], key=lambda ind: ind[0]))
  #print(sorted([(fitness(tsp, ind), ind) for ind in offspring], key=lambda ind: ind[0]))
  combined = population + offspring
  ranked_individuals = sorted([(fitness(tsp, ind), ind) for ind in combined], key=lambda ind: ind[0])[0:len(population)]
  #print(ranked_individuals)
  return [ind for fit, ind in ranked_individuals]

# %%
# Only needed to import the file into colab, needs only to be run once
from google.colab import files
uploaded = files.upload()
filename = next(iter(uploaded))
matrix = np.genfromtxt(filename,delimiter=',')

tsp = TSP(matrix)

optimize(tsp)

# 3000 + 3000 (50its)  >>  22670.967669271264
# 3000 + 3000 (100its)  >>  12837.643185583667
# Out:
#      <input type="file" id="files-448552d6-2d1b-44b5-a817-73599ae37769" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-448552d6-2d1b-44b5-a817-73599ae37769">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tour100.csv to tour100 (7).csv
#
# Mean fitness:   997978073.2166555
# Best fitness:   200045473.994087
# ---------------------------------  ITERATION 0 ---------------------------------
# Mean fitness:   628746417.9371263
# Best fitness:   100049493.05083133
# ---------------------------------  ITERATION 1 ---------------------------------
# Mean fitness:   410080713.94196993
# Best fitness:   43917.85509513634
# ---------------------------------  ITERATION 2 ---------------------------------
# Mean fitness:   282880668.59457463
# Best fitness:   43917.85509513634
# ---------------------------------  ITERATION 3 ---------------------------------
# Mean fitness:   191147520.06072807
# Best fitness:   42942.9279458007
# ---------------------------------  ITERATION 4 ---------------------------------
# Mean fitness:   129713717.60038275
# Best fitness:   42942.9279458007
# ---------------------------------  ITERATION 5 ---------------------------------
# Mean fitness:   73913902.3195857
# Best fitness:   42079.31848696719
# ---------------------------------  ITERATION 6 ---------------------------------
# Mean fitness:   40480061.28747351
# Best fitness:   41892.77497108684
# ---------------------------------  ITERATION 7 ---------------------------------
# Mean fitness:   47147.62014270713
# Best fitness:   41266.431504690525
# ---------------------------------  ITERATION 8 ---------------------------------
# Mean fitness:   45291.06140795542
# Best fitness:   40358.037110779216
# ---------------------------------  ITERATION 9 ---------------------------------
# Mean fitness:   43952.91275026349
# Best fitness:   39965.24191815081
# ---------------------------------  ITERATION 10 ---------------------------------
# Mean fitness:   42944.95573003297
# Best fitness:   39327.86805896588
# ---------------------------------  ITERATION 11 ---------------------------------
# Mean fitness:   42121.8622558482
# Best fitness:   37963.53264770807
# ---------------------------------  ITERATION 12 ---------------------------------
# Mean fitness:   41379.733110550646
# Best fitness:   36176.01408942547
# ---------------------------------  ITERATION 13 ---------------------------------
# Mean fitness:   40632.18127900145
# Best fitness:   35767.06591113363
# ---------------------------------  ITERATION 14 ---------------------------------
# Mean fitness:   39876.64522421328
# Best fitness:   34290.01672233518
# ---------------------------------  ITERATION 15 ---------------------------------
# Mean fitness:   39139.4703306994
# Best fitness:   33747.42894883476
# ---------------------------------  ITERATION 16 ---------------------------------
# Mean fitness:   38376.128679155474
# Best fitness:   33990.49959501219
# ---------------------------------  ITERATION 17 ---------------------------------
# Mean fitness:   37625.63962179245
# Best fitness:   33958.87606621973
# ---------------------------------  ITERATION 18 ---------------------------------
# Mean fitness:   36938.68270872912
# Best fitness:   33387.12903126707
# ---------------------------------  ITERATION 19 ---------------------------------
# Mean fitness:   36255.617760049885
# Best fitness:   32456.58263611078
# ---------------------------------  ITERATION 20 ---------------------------------
# Mean fitness:   35580.10728058359
# Best fitness:   31814.261796667608
# ---------------------------------  ITERATION 21 ---------------------------------
# Mean fitness:   34913.641815785915
# Best fitness:   31814.261796667608
# ---------------------------------  ITERATION 22 ---------------------------------
# Mean fitness:   34343.75502338161
# Best fitness:   31646.410037328562
# ---------------------------------  ITERATION 23 ---------------------------------
# Mean fitness:   33823.47740023737
# Best fitness:   31072.39474583508
# ---------------------------------  ITERATION 24 ---------------------------------
# Mean fitness:   33345.9584897446
# Best fitness:   29712.54377551011
# ---------------------------------  ITERATION 25 ---------------------------------
# Mean fitness:   32861.25616517663
# Best fitness:   29712.54377551011
# ---------------------------------  ITERATION 26 ---------------------------------
# Mean fitness:   32374.494927977586
# Best fitness:   29469.38027468026
# ---------------------------------  ITERATION 27 ---------------------------------
# Mean fitness:   31907.039213952798
# Best fitness:   29195.59636741914
# ---------------------------------  ITERATION 28 ---------------------------------
# Mean fitness:   31471.62240878591
# Best fitness:   28718.43959851499
# ---------------------------------  ITERATION 29 ---------------------------------
# Mean fitness:   31021.006200893804
# Best fitness:   28472.70499769968
# ---------------------------------  ITERATION 30 ---------------------------------
# Mean fitness:   30583.003016721614
# Best fitness:   27835.150590050656
# ---------------------------------  ITERATION 31 ---------------------------------
# Mean fitness:   30183.010007045592
# Best fitness:   27613.635944711405
# ---------------------------------  ITERATION 32 ---------------------------------
# Mean fitness:   29799.248228740875
# Best fitness:   27348.378717625987
# ---------------------------------  ITERATION 33 ---------------------------------
# Mean fitness:   29448.790786792673
# Best fitness:   26978.09129534175
# ---------------------------------  ITERATION 34 ---------------------------------
# Mean fitness:   29108.049550738873
# Best fitness:   25572.28322400103
# ---------------------------------  ITERATION 35 ---------------------------------
# Mean fitness:   28767.058861147136
# Best fitness:   25572.28322400103
# ---------------------------------  ITERATION 36 ---------------------------------
# Mean fitness:   28419.29094383972
# Best fitness:   25553.994602454288
# ---------------------------------  ITERATION 37 ---------------------------------
# Mean fitness:   28071.73286818975
# Best fitness:   25553.994602454288
# ---------------------------------  ITERATION 38 ---------------------------------
# Mean fitness:   27724.32156063545
# Best fitness:   25553.994602454288
# ---------------------------------  ITERATION 39 ---------------------------------
# Mean fitness:   27356.595394621283
# Best fitness:   25026.622702600638
# ---------------------------------  ITERATION 40 ---------------------------------
# Mean fitness:   26963.60665927614
# Best fitness:   24584.53774124409
# ---------------------------------  ITERATION 41 ---------------------------------
# Mean fitness:   26579.295108952643
# Best fitness:   24584.53774124409
# ---------------------------------  ITERATION 42 ---------------------------------
# Mean fitness:   26220.421373087232
# Best fitness:   24444.120723807075
# ---------------------------------  ITERATION 43 ---------------------------------
# Mean fitness:   25890.99445323556
# Best fitness:   23912.040598703086
# ---------------------------------  ITERATION 44 ---------------------------------
# Mean fitness:   25584.338251789617
# Best fitness:   23429.789416291558
# ---------------------------------  ITERATION 45 ---------------------------------
# Mean fitness:   25304.871484323758
# Best fitness:   23274.402545089797
# ---------------------------------  ITERATION 46 ---------------------------------
# Mean fitness:   25042.34440810173
# Best fitness:   23248.859235966756
# ---------------------------------  ITERATION 47 ---------------------------------
# Mean fitness:   24767.345166662242
# Best fitness:   22300.748300771924
# ---------------------------------  ITERATION 48 ---------------------------------
# Mean fitness:   24507.91855695596
# Best fitness:   22300.748300771924
# ---------------------------------  ITERATION 49 ---------------------------------
# Mean fitness:   24232.717890681124
# Best fitness:   22130.994503923834
# ---------------------------------  ITERATION 50 ---------------------------------
# Mean fitness:   23952.134452113718
# Best fitness:   21518.929052925607
# ---------------------------------  ITERATION 51 ---------------------------------
# Mean fitness:   23706.35590028802
# Best fitness:   21518.929052925607
# ---------------------------------  ITERATION 52 ---------------------------------
# Mean fitness:   23446.697212113915
# Best fitness:   21352.765362785423
# ---------------------------------  ITERATION 53 ---------------------------------
# Mean fitness:   23151.770833644707
# Best fitness:   21352.765362785423
# ---------------------------------  ITERATION 54 ---------------------------------
# Mean fitness:   22806.995965041464
# Best fitness:   21188.862782837667
# ---------------------------------  ITERATION 55 ---------------------------------
# Mean fitness:   22435.374047816313
# Best fitness:   21082.985663990723
# ---------------------------------  ITERATION 56 ---------------------------------
# Mean fitness:   22116.64600618035
# Best fitness:   20875.755032117886
# ---------------------------------  ITERATION 57 ---------------------------------
# Mean fitness:   21859.212859040625
# Best fitness:   20255.288311038905
# ---------------------------------  ITERATION 58 ---------------------------------
# Mean fitness:   21610.08954490402
# Best fitness:   20234.139049278787
# ---------------------------------  ITERATION 59 ---------------------------------
# Mean fitness:   21376.182334917074
# Best fitness:   19967.567527745705
# ---------------------------------  ITERATION 60 ---------------------------------
# Mean fitness:   21143.24567972285
# Best fitness:   19408.783829989465
# ---------------------------------  ITERATION 61 ---------------------------------
# Mean fitness:   20914.44306207789
# Best fitness:   19408.783829989465
# ---------------------------------  ITERATION 62 ---------------------------------
# Mean fitness:   20682.344939158964
# Best fitness:   19405.223315743133
# ---------------------------------  ITERATION 63 ---------------------------------
# Mean fitness:   20463.695513333678
# Best fitness:   19036.860832764167
# ---------------------------------  ITERATION 64 ---------------------------------
# Mean fitness:   20227.32430953364
# Best fitness:   18770.78455028946
# ---------------------------------  ITERATION 65 ---------------------------------
# Mean fitness:   19980.421042668597
# Best fitness:   18431.412650042006
# ---------------------------------  ITERATION 66 ---------------------------------
# Mean fitness:   19719.994654078193
# Best fitness:   18431.412650042006
# ---------------------------------  ITERATION 67 ---------------------------------
# Mean fitness:   19471.79946399119
# Best fitness:   18131.222007537188
# ---------------------------------  ITERATION 68 ---------------------------------
# Mean fitness:   19246.1568241405
# Best fitness:   17744.15817731604
# ---------------------------------  ITERATION 69 ---------------------------------
# Mean fitness:   19025.535926655015
# Best fitness:   17744.15817731604
# ---------------------------------  ITERATION 70 ---------------------------------
# Mean fitness:   18802.07575331617
# Best fitness:   17613.674375098588
# ---------------------------------  ITERATION 71 ---------------------------------
# Mean fitness:   18584.39167114688
# Best fitness:   17243.08008902127
# ---------------------------------  ITERATION 72 ---------------------------------
# Mean fitness:   18362.844958869162
# Best fitness:   17035.645627009966
# ---------------------------------  ITERATION 73 ---------------------------------
# Mean fitness:   18108.29919905031
# Best fitness:   16818.867731675335
# ---------------------------------  ITERATION 74 ---------------------------------
# Mean fitness:   17843.056886483897
# Best fitness:   16549.808810778373
# ---------------------------------  ITERATION 75 ---------------------------------
# Mean fitness:   17571.84178520322
# Best fitness:   16419.022038518615
# ---------------------------------  ITERATION 76 ---------------------------------
# Mean fitness:   17343.169006104337
# Best fitness:   16182.205122958037
# ---------------------------------  ITERATION 77 ---------------------------------
# Mean fitness:   17157.266260172964
# Best fitness:   16179.627874269909
# ---------------------------------  ITERATION 78 ---------------------------------
# Mean fitness:   16986.528768622076
# Best fitness:   15742.610987755443
# ---------------------------------  ITERATION 79 ---------------------------------
# Mean fitness:   16807.691645546893
# Best fitness:   15742.610987755443
# ---------------------------------  ITERATION 80 ---------------------------------
# Mean fitness:   16633.617152309846
# Best fitness:   15234.305053668815
# ---------------------------------  ITERATION 81 ---------------------------------
# Mean fitness:   16461.392253520648
# Best fitness:   15095.319986257591
# ---------------------------------  ITERATION 82 ---------------------------------
# Mean fitness:   16268.06425213285
# Best fitness:   15095.319986257591
# ---------------------------------  ITERATION 83 ---------------------------------
# Mean fitness:   16051.333488250246
# Best fitness:   15055.397955751472
# ---------------------------------  ITERATION 84 ---------------------------------
# Mean fitness:   15818.993406205456
# Best fitness:   14898.08377086467
# ---------------------------------  ITERATION 85 ---------------------------------
# Mean fitness:   15590.634428117528
# Best fitness:   14821.512865036242
# ---------------------------------  ITERATION 86 ---------------------------------
# Mean fitness:   15375.864950782885
# Best fitness:   14713.324797388213
# ---------------------------------  ITERATION 87 ---------------------------------
# Mean fitness:   15185.85556345409
# Best fitness:   14358.713078887227
# ---------------------------------  ITERATION 88 ---------------------------------
# Mean fitness:   15042.328451578478
# Best fitness:   14273.612484287645
# ---------------------------------  ITERATION 89 ---------------------------------
# Mean fitness:   14904.464542869846
# Best fitness:   14273.612484287645
# ---------------------------------  ITERATION 90 ---------------------------------
# Mean fitness:   14781.657472620022
# Best fitness:   14198.503331465357
# ---------------------------------  ITERATION 91 ---------------------------------
# Mean fitness:   14654.866267339725
# Best fitness:   14015.652505477281
# ---------------------------------  ITERATION 92 ---------------------------------
# Mean fitness:   14518.9668589483
# Best fitness:   13835.595714013507
# ---------------------------------  ITERATION 93 ---------------------------------
# Mean fitness:   14363.970123776073
# Best fitness:   13801.123461893802
# ---------------------------------  ITERATION 94 ---------------------------------
# Mean fitness:   14229.05370090404
# Best fitness:   13530.242399152652
# ---------------------------------  ITERATION 95 ---------------------------------
# Mean fitness:   14093.161974798268
# Best fitness:   13491.0950693639
# ---------------------------------  ITERATION 96 ---------------------------------
# Mean fitness:   13943.401767657235
# Best fitness:   13340.438856625819
# ---------------------------------  ITERATION 97 ---------------------------------
# Mean fitness:   13811.4505199857
# Best fitness:   13147.224746446582
# ---------------------------------  ITERATION 98 ---------------------------------
# Mean fitness:   13674.947430768789
# Best fitness:   12837.643185583667
# ---------------------------------  ITERATION 99 ---------------------------------
# Mean fitness:   13509.441351761776
# Best fitness:   12837.643185583667
# [10 28 50 65 42 67 89 43 58 61 87 83 0 37 53 3 26 52 81 60 2 47 86 39 32
#  74 73 57 49 95 17 34 78 85 33 1 90 44 40 97 92 98 24 80 16 20 55 71 68 56
#  19 5 18 59 23 76 29 27 69 70 77 22 96 63 48 25 35 8 41 12 66 11 30 9 99
#  75 31 21 82 62 45 7 93 72 15 38 4 51 13 54 14 94 84 88 46 6 36 64 79 91]
