# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimebaldeon/TSP-evolutionary-algorithm/blob/main/TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statistics
import random

class TSP:
  def __init__(self, numVertices):
    #self.vertices = [n for n in range(1, numVertices+1)] #to accomplish natural values for vertices
    self.vertices = [n for n in range(numVertices)]
    matrix = np.random.randint(100, 500, size=(numVertices, numVertices))
    np.fill_diagonal(matrix, 0)
    self.distanceMatrix = matrix

class Individual:
  def __init__(self, tsp):
    self.order = np.random.permutation(tsp.vertices)
    self.α = 0.05

def fitness(tsp, ind):
  value = 0
  ii = 0
  for i in ind.order:
    # Sum up total distance for the individual's sequence of nodes 
    while (ii < ind.order.size - 1):
      pairVertices = ind.order[ii:ii+2]
      value += tsp.distanceMatrix[pairVertices[0], pairVertices[1]]
      ii += 1 
  # add the distance between first and last node
  value += tsp.distanceMatrix[ind.order[-1], ind.order[0]]
  return value

def optimize(tsp):
  λ = 100 # population size
  μ = 100 # offspring size
  iter =100

  # Initialization
  population = initialize(tsp,λ)
  offspring = []

  # Print initial Candidate solutions
  for ind in population:
    print("Candidate solution:  ", ind.order)

  # Print initial Population evaluation
  fitnesses = [fitness(tsp, ind) for ind in population]
  print("\nMean fitness:  ", statistics.mean(fitnesses))
  print("Best fitness:  ", min(fitnesses))

  for i in range(iter):
    # Recombination
    for ind in range(μ):
      # Selection
      parent1 = selection(tsp, population)
      parent2 = selection(tsp, population)
      offspring.append(recombination(parent1, parent2))
      mutate(offspring[ind])

    # Mutation
    for ind in population:
      mutate(ind)    

    # Elimination
    population = elimination(population, offspring, tsp)

    fitnesses = [fitness(tsp, ind) for ind in population]
    print(f'---------------------------------  ITERATION {i} ---------------------------------')
    print("Mean fitness:  ", statistics.mean(fitnesses))
    print("Best fitness:  ", min(fitnesses))

  # Print final Candidate solutions
  for ind in population:
    print("Candidate solution:  ", ind.order)
    print("Candidate mutation probability:  ", ind.α)


def initialize(tsp, λ):
  population = []
  for i in range(λ):
    population.append(Individual(tsp))
  return population

def mutate(individual):
  if np.random.rand() < individual.α:
    i = random.randrange(len(individual.order))
    j = random.randrange(len(individual.order))
    if i < j:
      individual.order[i:j] = individual.order[i:j][::-1]
    else:
      individual.order[j:i] = individual.order[j:i][::-1]

def recombination(parent1, parent2):
  child = parent1
  # Select crossover points randomly
  i = random.randrange(len(parent1.order))
  j = random.randrange(len(parent1.order))
  # Perform order crossover recombination to create the child's order
  if i < j:  
    child.order = order_crossover(parent1.order, parent2.order, i, j)
  else:  
    child.order = order_crossover(parent1.order, parent2.order, j, i)  
  # Set child parameters
  β = 2 * np.random.rand() - 0.5 # coefficient between (-0.5, 1.5)
  child.α = parent1.α + β * (parent2.α - parent1.α)
  return child

def order_crossover(parent1, parent2, i,j):
  # Create loop effect over array
  p1 = np.concatenate((parent1, parent1), axis=None)
  p2 = np.concatenate((parent2, parent2), axis=None)
  # Create empty child order
  child = np.full(len(parent2), None) 
  # Fill child with random selected sequence from parent1
  child[i:j] = p1[i:j]
  # Set pointers to the second crossover point in parent2 (jj) and child (ii)
  ii, jj = j, j
  # The recombination stops when all nodes in parent2 sequence have been added to the child
  while (jj < j + len(parent2)):
    if ii > len(parent2)-1:
      # when child's pointer reaches the end of the array go to position 0
      ii = 0
    if p2[jj] not in child: 
      # Missing nodes are added to the child
      child[ii] = p2[jj]
      ii += 1 # when added a new node, shift child's pointer to the left
    jj += 1
  return child

def selection(tsp, population):
  k = 5
  candidates = random.sample(population, k)
  fitnesses = [fitness(tsp, ind) for ind in candidates]
  selected = fitnesses.index(min(fitnesses))
  return candidates[selected]

def elimination(population, offspring, tsp):
  # λ+μ elimination
  combined = population + offspring
  ranked_individuals = sorted([(fitness(tsp, ind), ind) for ind in combined], key=lambda ind: ind[0])[0:len(population)]
  return [ind for fit, ind in ranked_individuals]

# %%
tsp = TSP(5)
population=initialize(tsp,15)
for i in population:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

parent1 = selection(tsp, population)
parent2 = selection(tsp, population)
print(f'\n Selected parent {parent1.order} y fitness: {fitness(tsp, parent1)}')
print(f'\n Selected parent {parent2.order} y fitness: {fitness(tsp, parent2)}')

offspring = recombination(parent1, parent2)
print(f'\n Offspring recombination {offspring.order} y fitness: {fitness(tsp, offspring)}')

mutate(offspring)
print(f'\n Offspring mutated {offspring.order} y fitness: {fitness(tsp, offspring)}')

# Mutation
for ind in population:
  mutate(ind)    

off = [offspring]
# Elimination
population = elimination(population, off, tsp)
for i in population:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

# %%
tsp = TSP(5)

#print("Vertices:  ", tsp.vertices)
print("Distance:  \n", tsp.distanceMatrix)

optimize(tsp)

"""best = elimination(pop, pop, tsp)
for i in best:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

fitnesses = [fitness(tsp, ind) for ind in best]
print("\nMean fitness:  ", statistics.mean(fitnesses))
print("Best fitness:  ", min(fitnesses))
"""
# Out:
# Distance:
#  [[  0 345 243 284 171]
#  [170   0 392 248 150]
#  [437 253   0 244 419]
#  [395 402 197   0 464]
#  [454 374 269 228   0]]
# Candidate solution:   [3 4 1 2 0]
# Candidate solution:   [3 1 2 0 4]
# Candidate solution:   [1 4 3 2 0]
# Candidate solution:   [1 2 4 0 3]
# Candidate solution:   [1 0 3 4 2]
# Candidate solution:   [3 0 1 2 4]
# Candidate solution:   [1 2 0 4 3]
# Candidate solution:   [2 4 0 1 3]
# Candidate solution:   [4 0 3 2 1]
# Candidate solution:   [3 4 0 1 2]
# Candidate solution:   [1 0 3 4 2]
# Candidate solution:   [2 0 1 4 3]
# Candidate solution:   [1 4 3 2 0]
# Candidate solution:   [0 2 1 4 3]
# Candidate solution:   [2 3 4 1 0]
# Candidate solution:   [0 2 4 1 3]
# Candidate solution:   [4 1 0 3 2]
# Candidate solution:   [3 2 4 1 0]
# Candidate solution:   [0 4 3 1 2]
# Candidate solution:   [2 4 0 3 1]
# Candidate solution:   [2 0 4 3 1]
# Candidate solution:   [4 0 3 2 1]
# Candidate solution:   [1 3 4 0 2]
# Candidate solution:   [1 4 3 0 2]
# Candidate solution:   [1 3 2 0 4]
# Candidate solution:   [0 2 1 3 4]
# Candidate solution:   [1 0 2 4 3]
# Candidate solution:   [3 4 0 1 2]
# Candidate solution:   [2 1 4 3 0]
# Candidate solution:   [2 1 0 3 4]
# Candidate solution:   [0 4 1 3 2]
# Candidate solution:   [0 2 3 4 1]
# Candidate solution:   [0 2 1 3 4]
# Candidate solution:   [1 3 2 0 4]
# Candidate solution:   [0 1 2 4 3]
# Candidate solution:   [3 0 2 1 4]
# Candidate solution:   [0 3 2 4 1]
# Candidate solution:   [2 1 4 3 0]
# Candidate solution:   [2 4 0 1 3]
# Candidate solution:   [4 0 2 1 3]
# Candidate solution:   [4 2 0 1 3]
# Candidate solution:   [1 4 3 2 0]
# Candidate solution:   [3 1 4 0 2]
# Candidate solution:   [2 4 3 1 0]
# Candidate solution:   [2 1 4 0 3]
# Candidate solution:   [3 2 4 1 0]
# Candidate solution:   [2 0 4 1 3]
# Candidate solution:   [3 0 4 2 1]
# Candidate solution:   [0 3 1 4 2]
# Candidate solution:   [2 0 4 1 3]
# Candidate solution:   [4 1 3 0 2]
# Candidate solution:   [2 0 3 1 4]
# Candidate solution:   [4 3 2 1 0]
# Candidate solution:   [3 0 1 4 2]
# Candidate solution:   [3 0 4 1 2]
# Candidate solution:   [4 2 3 0 1]
# Candidate solution:   [2 4 3 0 1]
# Candidate solution:   [2 3 0 4 1]
# Candidate solution:   [1 4 3 0 2]
# Candidate solution:   [3 0 1 2 4]
# Candidate solution:   [4 3 1 2 0]
# Candidate solution:   [3 4 2 0 1]
# Candidate solution:   [4 2 3 1 0]
# Candidate solution:   [0 3 1 2 4]
# Candidate solution:   [4 1 2 3 0]
# Candidate solution:   [2 1 0 4 3]
# Candidate solution:   [2 4 1 3 0]
# Candidate solution:   [0 1 2 4 3]
# Candidate solution:   [4 0 2 1 3]
# Candidate solution:   [1 2 0 4 3]
# Candidate solution:   [4 1 0 2 3]
# Candidate solution:   [1 2 3 4 0]
# Candidate solution:   [0 4 3 1 2]
# Candidate solution:   [1 4 3 0 2]
# Candidate solution:   [1 0 3 2 4]
# Candidate solution:   [3 0 2 1 4]
# Candidate solution:   [2 1 0 4 3]
# Candidate solution:   [4 0 3 1 2]
# Candidate solution:   [0 1 2 3 4]
# Candidate solution:   [4 0 3 1 2]
# Candidate solution:   [0 3 1 2 4]
# Candidate solution:   [3 4 0 1 2]
# Candidate solution:   [3 2 0 4 1]
# Candidate solution:   [4 0 2 3 1]
# Candidate solution:   [2 0 1 3 4]
# Candidate solution:   [0 3 4 2 1]
# Candidate solution:   [2 1 0 4 3]
# Candidate solution:   [1 2 0 4 3]
# Candidate solution:   [3 2 0 1 4]
# Candidate solution:   [4 2 0 3 1]
# Candidate solution:   [3 2 0 4 1]
# Candidate solution:   [4 3 1 0 2]
# Candidate solution:   [1 2 4 3 0]
# Candidate solution:   [4 0 2 3 1]
# Candidate solution:   [3 1 0 2 4]
# Candidate solution:   [0 2 4 1 3]
# Candidate solution:   [4 3 1 2 0]
# Candidate solution:   [4 2 0 1 3]
# Candidate solution:   [4 2 3 0 1]
# Candidate solution:   [1 4 2 0 3]
#
# Mean fitness:   1544
# Best fitness:   1019
# ---------------------------------  ITERATION 0 ---------------------------------
# Mean fitness:   1418
# Best fitness:   1256
# ---------------------------------  ITERATION 1 ---------------------------------
# Mean fitness:   1449
# Best fitness:   1338
# ---------------------------------  ITERATION 2 ---------------------------------
# Mean fitness:   1386
# Best fitness:   1269
# ---------------------------------  ITERATION 3 ---------------------------------
# Mean fitness:   1171
# Best fitness:   1019
# ---------------------------------  ITERATION 4 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 5 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 6 ---------------------------------
# Mean fitness:   1444
# Best fitness:   1269
# ---------------------------------  ITERATION 7 ---------------------------------
# Mean fitness:   1421
# Best fitness:   1269
# ---------------------------------  ITERATION 8 ---------------------------------
# Mean fitness:   1354
# Best fitness:   1019
# ---------------------------------  ITERATION 9 ---------------------------------
# Mean fitness:   1335
# Best fitness:   1269
# ---------------------------------  ITERATION 10 ---------------------------------
# Mean fitness:   1256
# Best fitness:   1256
# ---------------------------------  ITERATION 11 ---------------------------------
# Mean fitness:   1417
# Best fitness:   1256
# ---------------------------------  ITERATION 12 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1269
# ---------------------------------  ITERATION 13 ---------------------------------
# Mean fitness:   1462
# Best fitness:   1462
# ---------------------------------  ITERATION 14 ---------------------------------
# Mean fitness:   1493
# Best fitness:   1493
# ---------------------------------  ITERATION 15 ---------------------------------
# Mean fitness:   1358
# Best fitness:   1269
# ---------------------------------  ITERATION 16 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 17 ---------------------------------
# Mean fitness:   1355
# Best fitness:   1336
# ---------------------------------  ITERATION 18 ---------------------------------
# Mean fitness:   1412
# Best fitness:   1336
# ---------------------------------  ITERATION 19 ---------------------------------
# Mean fitness:   1434
# Best fitness:   1427
# ---------------------------------  ITERATION 20 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1357
# ---------------------------------  ITERATION 21 ---------------------------------
# Mean fitness:   1430
# Best fitness:   1427
# ---------------------------------  ITERATION 22 ---------------------------------
# Mean fitness:   1403
# Best fitness:   1403
# ---------------------------------  ITERATION 23 ---------------------------------
# Mean fitness:   1450
# Best fitness:   1269
# ---------------------------------  ITERATION 24 ---------------------------------
# Mean fitness:   1317
# Best fitness:   1256
# ---------------------------------  ITERATION 25 ---------------------------------
# Mean fitness:   1256
# Best fitness:   1256
# ---------------------------------  ITERATION 26 ---------------------------------
# Mean fitness:   1496
# Best fitness:   1256
# ---------------------------------  ITERATION 27 ---------------------------------
# Mean fitness:   1403
# Best fitness:   1403
# ---------------------------------  ITERATION 28 ---------------------------------
# Mean fitness:   1432
# Best fitness:   1403
# ---------------------------------  ITERATION 29 ---------------------------------
# Mean fitness:   1331
# Best fitness:   1256
# ---------------------------------  ITERATION 30 ---------------------------------
# Mean fitness:   1457
# Best fitness:   1427
# ---------------------------------  ITERATION 31 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 32 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 33 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 34 ---------------------------------
# Mean fitness:   1462
# Best fitness:   1462
# ---------------------------------  ITERATION 35 ---------------------------------
# Mean fitness:   1488
# Best fitness:   1440
# ---------------------------------  ITERATION 36 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# ---------------------------------  ITERATION 37 ---------------------------------
# Mean fitness:   1444
# Best fitness:   1336
# ---------------------------------  ITERATION 38 ---------------------------------
# Mean fitness:   1385
# Best fitness:   1336
# ---------------------------------  ITERATION 39 ---------------------------------
# Mean fitness:   1383
# Best fitness:   1256
# ---------------------------------  ITERATION 40 ---------------------------------
# Mean fitness:   1462
# Best fitness:   1462
# ---------------------------------  ITERATION 41 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 42 ---------------------------------
# Mean fitness:   1323
# Best fitness:   1269
# ---------------------------------  ITERATION 43 ---------------------------------
# Mean fitness:   1378
# Best fitness:   1269
# ---------------------------------  ITERATION 44 ---------------------------------
# Mean fitness:   1486
# Best fitness:   1462
# ---------------------------------  ITERATION 45 ---------------------------------
# Mean fitness:   1505
# Best fitness:   1462
# ---------------------------------  ITERATION 46 ---------------------------------
# Mean fitness:   1443
# Best fitness:   1440
# ---------------------------------  ITERATION 47 ---------------------------------
# Mean fitness:   1403
# Best fitness:   1403
# ---------------------------------  ITERATION 48 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1357
# ---------------------------------  ITERATION 49 ---------------------------------
# Mean fitness:   1462
# Best fitness:   1462
# ---------------------------------  ITERATION 50 ---------------------------------
# Mean fitness:   1489
# Best fitness:   1462
# ---------------------------------  ITERATION 51 ---------------------------------
# Mean fitness:   1519
# Best fitness:   1444
# ---------------------------------  ITERATION 52 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# ---------------------------------  ITERATION 53 ---------------------------------
# Mean fitness:   1435
# Best fitness:   1357
# ---------------------------------  ITERATION 54 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 55 ---------------------------------
# Mean fitness:   1248
# Best fitness:   1019
# ---------------------------------  ITERATION 56 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 57 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1357
# ---------------------------------  ITERATION 58 ---------------------------------
# Mean fitness:   1439
# Best fitness:   1427
# ---------------------------------  ITERATION 59 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 60 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 61 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 62 ---------------------------------
# Mean fitness:   1385
# Best fitness:   1256
# ---------------------------------  ITERATION 63 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# ---------------------------------  ITERATION 64 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# ---------------------------------  ITERATION 65 ---------------------------------
# Mean fitness:   1403
# Best fitness:   1403
# ---------------------------------  ITERATION 66 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 67 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1357
# ---------------------------------  ITERATION 68 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 69 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 70 ---------------------------------
# Mean fitness:   1426
# Best fitness:   1403
# ---------------------------------  ITERATION 71 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# ---------------------------------  ITERATION 72 ---------------------------------
# Mean fitness:   1443
# Best fitness:   1440
# ---------------------------------  ITERATION 73 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1357
# ---------------------------------  ITERATION 74 ---------------------------------
# Mean fitness:   1217
# Best fitness:   1019
# ---------------------------------  ITERATION 75 ---------------------------------
# Mean fitness:   1442
# Best fitness:   1440
# ---------------------------------  ITERATION 76 ---------------------------------
# Mean fitness:   1391
# Best fitness:   1357
# ---------------------------------  ITERATION 77 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 78 ---------------------------------
# Mean fitness:   1021
# Best fitness:   1019
# ---------------------------------  ITERATION 79 ---------------------------------
# Mean fitness:   1267
# Best fitness:   1256
# ---------------------------------  ITERATION 80 ---------------------------------
# Mean fitness:   1307
# Best fitness:   1269
# ---------------------------------  ITERATION 81 ---------------------------------
# Mean fitness:   1269
# Best fitness:   1269
# ---------------------------------  ITERATION 82 ---------------------------------
# Mean fitness:   1357
# Best fitness:   1357
# ---------------------------------  ITERATION 83 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 84 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# ---------------------------------  ITERATION 85 ---------------------------------
# Mean fitness:   1424
# Best fitness:   1403
# ---------------------------------  ITERATION 86 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 87 ---------------------------------
# Mean fitness:   1444
# Best fitness:   1338
# ---------------------------------  ITERATION 88 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 89 ---------------------------------
# Mean fitness:   1420
# Best fitness:   1256
# ---------------------------------  ITERATION 90 ---------------------------------
# Mean fitness:   1475
# Best fitness:   1256
# ---------------------------------  ITERATION 91 ---------------------------------
# Mean fitness:   1440
# Best fitness:   1440
# ---------------------------------  ITERATION 92 ---------------------------------
# Mean fitness:   1444
# Best fitness:   1444
# ---------------------------------  ITERATION 93 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 94 ---------------------------------
# Mean fitness:   1256
# Best fitness:   1256
# ---------------------------------  ITERATION 95 ---------------------------------
# Mean fitness:   1336
# Best fitness:   1336
# ---------------------------------  ITERATION 96 ---------------------------------
# Mean fitness:   1019
# Best fitness:   1019
# ---------------------------------  ITERATION 97 ---------------------------------
# Mean fitness:   1403
# Best fitness:   1403
# ---------------------------------  ITERATION 98 ---------------------------------
# Mean fitness:   1427
# Best fitness:   1427
# ---------------------------------  ITERATION 99 ---------------------------------
# Mean fitness:   1338
# Best fitness:   1338
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# Candidate solution:   [4 0 3 2 1]
# Candidate mutation probability:   0.05
# 'best = elimination(pop, pop, tsp)\nfor i in best:\n  print("Candidate solution:  ", i.order)\n  print("Objective value: ", fitness(tsp, i))\n\nfitnesses = [fitness(tsp, ind) for ind in best]\nprint("\nMean fitness:  ", statistics.mean(fitnesses))\nprint("Best fitness:  ", min(fitnesses))\n'
