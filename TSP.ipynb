# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimebaldeon/TSP-evolutionary-algorithm/blob/main/TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statistics
import random

class TSP:
  def __init__(self, numVertices):
    #self.vertices = [n for n in range(1, numVertices+1)] #to accomplish natural values for vertices
    self.vertices = [n for n in range(numVertices)]
    matrix = np.random.randint(100, 500, size=(numVertices, numVertices))
    np.fill_diagonal(matrix, 0)
    self.distanceMatrix = matrix

class Individual:
  def __init__(self, tsp):
    self.order = np.random.permutation(tsp.vertices)
    self.α = 0.1

def fitness(tsp, ind):
  value = 0
  ii = 0
  for i in ind.order:
    # Sum up total distance for the individual's sequence of nodes 
    while (ii < ind.order.size - 1):
      pairVertices = ind.order[ii:ii+2]
      value += tsp.distanceMatrix[pairVertices[0], pairVertices[1]]
      ii += 1 
  # add the distance between first and last node
  value += tsp.distanceMatrix[ind.order[-1], ind.order[0]]
  return value

def optimize(tsp):
  λ = 100 # population size
  μ = 100 # offspring size
  iter =100

  # Initialization
  population = initialize(tsp,λ)
  offspring = []

  # Print initial Candidate solutions
  for ind in population:
    print("Candidate solution:  ", ind.order)

  # Print initial Population evaluation
  fitnesses = [fitness(tsp, ind) for ind in population]
  print("\nMean fitness:  ", statistics.mean(fitnesses))
  print("Best fitness:  ", min(fitnesses))

  for i in range(iter):
    # Recombination
    for ind in range(μ):
      # Selection
      parent1 = selection(tsp, population)
      parent2 = selection(tsp, population)
      offspring.append(recombination(parent1, parent2))
      mutate(offspring[ind])

    # Mutation
    for ind in population:
      mutate(ind)    

    # Elimination
    population = elimination(population, offspring, tsp)

    fitnesses = [fitness(tsp, ind) for ind in population]
    print(f'---------------------------------  ITERATION {i} ---------------------------------')
    print("Mean fitness:  ", statistics.mean(fitnesses))
    print("Best fitness:  ", min(fitnesses))

  # Print final Candidate solutions
  for ind in population:
    print("Candidate solution:  ", ind.order)
    print("Candidate mutation probability:  ", ind.α)


def initialize(tsp, λ):
  population = []
  for i in range(λ):
    population.append(Individual(tsp))
  return population

def mutate(individual):
  if np.random.rand() < individual.α:
    i = random.randrange(len(individual.order))
    j = random.randrange(len(individual.order))
    if i < j:
      individual.order[i:j] = individual.order[i:j][::-1]
    else:
      individual.order[j:i] = individual.order[j:i][::-1]

def recombination(parent1, parent2):
  # find common subsequences and give to child
  child = parent1
  # Find cycles shared by parents
  sharedCycles = matched_subseq(parent1.order, parent2.order)
  # Add the other nodes randomly 
  empty = False
  if sharedCycles.size == 0:
    empty = True
  order = sharedCycles # child nodes order
  node = 0
  while (node < parent1.order.size):
    # Non-common cycle nodes are concatenated randomly before or after shared cycles 
    if not search_sequence(np.array([node]), sharedCycles) or empty:
      if np.random.rand() < 0.5:
        order = np.concatenate((order, np.array(node)), axis=None)
      else:
        order = np.concatenate((np.array(node), order), axis=None)
    node += 1
  # Set child parameters
  child.order = order
  β = 2 * np.random.rand() - 0.5 # coefficient between (-0.5, 1.5)
  child.α = parent1.α + β * (parent2.α - parent1.α)
  return child

def selection(tsp, population):
  k = 5
  candidates = random.sample(population, k)
  fitnesses = [fitness(tsp, ind) for ind in candidates]
  selected = fitnesses.index(min(fitnesses))
  return candidates[selected]

def elimination(population, offspring, tsp):
  # λ+μ elimination
  combined = population + offspring
  ranked_individuals = sorted([(fitness(tsp, ind), ind) for ind in combined], key=lambda ind: ind[0])[0:len(population)]
  return [ind for fit, ind in ranked_individuals]

def matched_subseq(parent1, parent2):
  # Mejor ponerlos aleatoriamente para mas exploracion en vez de concat
  # CAREFUL [1,2,3,4] = [2,3,4,1]
  matchedSubseq = np.array([], dtype=int)
  window_size = 2
  window_pos = 0
  while window_pos < parent1.size:  
    # extract subsequence from parent
    subseq = parent1[window_pos:window_pos+window_size] #problem: last node is alone
    #print(subseq)
    # Search longest common subsequences
    matched = None
    num_matches = 0
    keepSearching = True
    while (keepSearching and window_pos+window_size <= parent1.size):
      # take the first individual again
      if search_sequence(parent2, subseq):
        # Save matching subsequence
        matched = subseq
        #print(f'Matched: {matched}')
        # If it is the last common subsequence we append it
        if window_pos+window_size is parent1.size: 
          matchedSubseq = np.concatenate((matchedSubseq, matched), axis=None)
          #print('appended subsequence:  ', matched)
        # Increase subsequence length
        num_matches += 1
        window_size += 1
        subseq = parent1[window_pos:window_pos+window_size]
        #print(f'{subseq} from {window_pos} to {window_pos+window_size}')
      else: 
        if matched is not None:
          matchedSubseq = np.concatenate((matchedSubseq, matched), axis=None)
        #print('appended subsequence:  ', matched)
        matched = None
        window_size = 2
        keepSearching = False
    window_pos += 1 + num_matches
  return matchedSubseq

def search_sequence(arr,seq):
    # Store sizes of input array and sequence
    Na, Nseq = arr.size, seq.size

    # Range of sequence
    r_seq = np.arange(Nseq)
    r_arr = np.arange(Na)
    # Create a 2D array of sliding indices across the entire length of input array.
    # Match up with the input sequence & get the matching starting indices.
    M = (arr[np.arange(Na-Nseq+1)[:,None] + r_seq] == seq).all(1)
    N = (seq[np.arange(Nseq-Na+1)[:,None] + r_arr] == arr).all(1)
    # Get the range of those indices as final output
    if M.any() >0 or N.any() > 0:
        return True
    else:
        return False         # No match found

# %%
def order_crossover(parent1, parent2, i,j):
  p1 = np.concatenate((parent1, parent1), axis=None)
  p2 = np.concatenate((parent2, parent2), axis=None)
  child = np.zeros(9, dtype=int) # change to Nan or sth not in the vertices dom
  child[i:j] = p1[i:j]
  print('Step1:   ', child)
  ii, jj = j, j
  while (jj < j + len(parent2)):
    print(p2[jj])
    if ii > 8:
      ii = 0
    if p2[jj] not in child: 
      child[ii] = p2[jj]
      print(child)
      ii += 1
    jj += 1
  return child

# Order crossover
parent1 = np.array(range(1,10))
parent2 = np.array([9,3,7,8,2,6,5,1,4])
print(parent1)
print(parent2)
i = random.randrange(len(parent1))
j = random.randrange(len(parent1))
if i < j:  
  print(order_crossover(parent1, parent2, i, j))
else:  
  print(order_crossover(parent1, parent2, j, i))
# Out:
# [1 2 3 4 5 6 7 8 9]
# [9 3 7 8 2 6 5 1 4]
# Step1:    [0 0 0 4 5 6 0 0 0]
# 5
# 1
# [0 0 0 4 5 6 1 0 0]
# 4
# 9
# [0 0 0 4 5 6 1 9 0]
# 3
# [0 0 0 4 5 6 1 9 3]
# 7
# [7 0 0 4 5 6 1 9 3]
# 8
# [7 8 0 4 5 6 1 9 3]
# 2
# [7 8 2 4 5 6 1 9 3]
# 6
# [7 8 2 4 5 6 1 9 3]

# %%
tsp = TSP(10)
population=initialize(tsp,15)
for i in population:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

parent1 = selection(tsp, population)
parent2 = selection(tsp, population)
print(f'\n Selected parent {parent1.order} y fitness: {fitness(tsp, parent1)}')
print(f'\n Selected parent {parent2.order} y fitness: {fitness(tsp, parent2)}')

offspring = recombination(parent1, parent2)
print(f'\n Offspring recombination {offspring.order} y fitness: {fitness(tsp, offspring)}')

mutate(offspring)
print(f'\n Offspring mutated {offspring.order} y fitness: {fitness(tsp, offspring)}')

# Mutation
for ind in population:
  mutate(ind)    

off = [offspring]
# Elimination
population = elimination(population, off, tsp)
for i in population:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))
# Out:
# Candidate solution:   [1 4 2 0 7 9 8 5 6 3]
# Objective value:  3276
# Candidate solution:   [0 9 2 6 8 3 4 5 1 7]
# Objective value:  3143
# Candidate solution:   [6 2 7 5 0 4 8 9 1 3]
# Objective value:  2497
# Candidate solution:   [3 2 4 1 5 7 6 9 0 8]
# Objective value:  2671
# Candidate solution:   [3 7 2 8 0 9 6 4 1 5]
# Objective value:  3036
# Candidate solution:   [0 5 6 4 2 8 3 7 9 1]
# Objective value:  2950
# Candidate solution:   [8 3 1 5 9 7 0 4 2 6]
# Objective value:  2431
# Candidate solution:   [0 1 5 3 4 7 6 9 8 2]
# Objective value:  2732
# Candidate solution:   [6 3 9 0 2 5 1 8 4 7]
# Objective value:  2741
# Candidate solution:   [7 3 0 2 5 8 9 4 6 1]
# Objective value:  3066
# Candidate solution:   [1 8 0 3 4 9 5 7 6 2]
# Objective value:  2332
# Candidate solution:   [5 2 6 1 3 7 8 9 4 0]
# Objective value:  2909
# Candidate solution:   [0 1 2 3 8 9 6 5 4 7]
# Objective value:  2828
# Candidate solution:   [5 4 0 3 1 6 7 9 2 8]
# Objective value:  3273
# Candidate solution:   [0 2 1 4 9 7 6 3 8 5]
# Objective value:  2814
#
#  Selected parent [6 3 9 0 2 5 1 8 4 7] y fitness: 2741
#
#  Selected parent [6 2 7 5 0 4 8 9 1 3] y fitness: 2497
#
#  Offspring recombination [7 5 2 0 1 3 4 6 8 9] y fitness: 3283
#
#  Offspring mutated [7 5 2 0 1 3 4 6 8 9] y fitness: 3283
# Candidate solution:   [1 8 0 3 4 9 5 7 6 2]
# Objective value:  2332
# Candidate solution:   [8 3 1 5 9 7 0 4 2 6]
# Objective value:  2431
# Candidate solution:   [6 2 7 1 9 8 4 0 5 3]
# Objective value:  2435
# Candidate solution:   [3 2 4 1 5 7 6 9 0 8]
# Objective value:  2671
# Candidate solution:   [0 1 5 3 4 7 6 9 8 2]
# Objective value:  2732
# Candidate solution:   [0 2 1 4 9 7 6 3 8 5]
# Objective value:  2814
# Candidate solution:   [0 1 2 3 8 9 6 5 4 7]
# Objective value:  2828
# Candidate solution:   [3 7 2 6 9 0 8 4 1 5]
# Objective value:  2843
# Candidate solution:   [5 2 6 1 3 7 8 9 4 0]
# Objective value:  2909
# Candidate solution:   [0 5 6 4 2 8 3 7 9 1]
# Objective value:  2950
# Candidate solution:   [7 3 0 2 5 8 9 4 6 1]
# Objective value:  3066
# Candidate solution:   [0 9 2 6 8 3 4 5 1 7]
# Objective value:  3143
# Candidate solution:   [5 4 0 3 1 6 7 9 2 8]
# Objective value:  3273
# Candidate solution:   [1 4 2 0 7 9 8 5 6 3]
# Objective value:  3276
# Candidate solution:   [7 5 2 0 1 3 4 6 8 9]
# Objective value:  3283

# %%
tsp = TSP(10)

#print("Vertices:  ", tsp.vertices)
#print("Distance:  \n", tsp.distanceMatrix)

optimize(tsp)

"""best = elimination(pop, pop, tsp)
for i in best:
  print("Candidate solution:  ", i.order)
  print("Objective value: ", fitness(tsp, i))

fitnesses = [fitness(tsp, ind) for ind in best]
print("\nMean fitness:  ", statistics.mean(fitnesses))
print("Best fitness:  ", min(fitnesses))
"""
# Out:
# Candidate solution:   [0 5 6 3 8 2 9 4 7 1]
# Candidate solution:   [2 6 4 9 8 3 7 5 1 0]
# Candidate solution:   [6 2 9 3 1 8 7 5 0 4]
# Candidate solution:   [1 5 0 7 8 3 4 9 6 2]
# Candidate solution:   [7 1 0 8 5 2 9 4 3 6]
# Candidate solution:   [1 8 3 0 6 2 4 9 5 7]
# Candidate solution:   [3 0 9 7 1 5 8 6 2 4]
# Candidate solution:   [2 8 0 9 6 3 7 5 1 4]
# Candidate solution:   [3 8 2 5 9 7 6 4 0 1]
# Candidate solution:   [2 7 9 3 0 5 1 4 8 6]
# Candidate solution:   [1 7 2 8 9 6 0 3 5 4]
# Candidate solution:   [6 8 5 4 2 9 7 3 1 0]
# Candidate solution:   [0 8 6 5 9 1 7 2 4 3]
# Candidate solution:   [0 6 7 5 8 2 1 4 3 9]
# Candidate solution:   [4 9 5 0 1 7 2 3 8 6]
# Candidate solution:   [7 9 6 4 3 2 5 8 1 0]
# Candidate solution:   [8 5 1 2 6 4 0 9 7 3]
# Candidate solution:   [5 0 7 6 2 9 4 1 3 8]
# Candidate solution:   [3 6 7 1 5 9 8 2 0 4]
# Candidate solution:   [9 1 5 7 6 3 8 2 0 4]
# Candidate solution:   [1 4 3 7 5 8 2 9 0 6]
# Candidate solution:   [4 1 0 2 7 8 6 5 3 9]
# Candidate solution:   [2 7 6 0 8 4 3 5 9 1]
# Candidate solution:   [6 0 3 1 8 4 5 2 9 7]
# Candidate solution:   [6 4 0 8 1 5 2 9 7 3]
# Candidate solution:   [0 5 8 1 2 9 4 6 7 3]
# Candidate solution:   [6 3 9 2 1 7 5 4 0 8]
# Candidate solution:   [4 2 9 8 3 6 5 1 7 0]
# Candidate solution:   [6 3 8 7 9 4 0 2 5 1]
# Candidate solution:   [1 0 2 5 7 3 4 9 8 6]
# Candidate solution:   [3 8 6 5 4 2 0 7 1 9]
# Candidate solution:   [7 3 8 6 4 5 2 0 1 9]
# Candidate solution:   [1 0 2 3 4 5 6 8 9 7]
# Candidate solution:   [9 8 3 4 6 7 2 1 5 0]
# Candidate solution:   [8 3 4 2 7 6 5 9 1 0]
# Candidate solution:   [4 8 5 1 0 3 9 2 6 7]
# Candidate solution:   [7 4 6 2 0 8 5 3 9 1]
# Candidate solution:   [7 9 4 6 2 5 3 0 1 8]
# Candidate solution:   [2 7 1 4 3 8 0 6 9 5]
# Candidate solution:   [4 5 7 9 2 3 0 8 1 6]
# Candidate solution:   [8 9 4 0 3 7 5 6 1 2]
# Candidate solution:   [0 3 2 1 9 8 4 7 6 5]
# Candidate solution:   [4 7 2 3 9 1 8 5 0 6]
# Candidate solution:   [8 6 5 9 0 3 4 7 2 1]
# Candidate solution:   [9 7 1 4 5 8 2 6 0 3]
# Candidate solution:   [2 7 4 5 0 3 6 1 9 8]
# Candidate solution:   [1 6 4 8 0 2 9 5 7 3]
# Candidate solution:   [2 1 5 4 3 7 9 8 0 6]
# Candidate solution:   [5 8 2 4 6 3 7 0 1 9]
# Candidate solution:   [5 9 3 1 8 7 4 2 0 6]
# Candidate solution:   [9 3 0 2 4 7 5 8 1 6]
# Candidate solution:   [7 4 5 0 1 8 2 3 6 9]
# Candidate solution:   [7 5 3 0 6 1 9 4 2 8]
# Candidate solution:   [3 1 6 7 5 2 4 9 0 8]
# Candidate solution:   [7 4 0 2 5 1 9 8 6 3]
# Candidate solution:   [2 9 5 1 3 4 6 7 8 0]
# Candidate solution:   [6 9 8 4 3 0 2 7 5 1]
# Candidate solution:   [5 2 1 3 8 4 7 0 9 6]
# Candidate solution:   [8 6 1 4 2 3 0 7 5 9]
# Candidate solution:   [8 0 2 5 3 7 6 1 4 9]
# Candidate solution:   [7 2 6 1 9 5 4 0 3 8]
# Candidate solution:   [9 0 6 4 8 1 3 7 2 5]
# Candidate solution:   [3 5 1 9 8 0 6 7 2 4]
# Candidate solution:   [2 3 7 5 8 0 1 4 6 9]
# Candidate solution:   [2 8 6 5 0 3 1 9 7 4]
# Candidate solution:   [9 2 6 7 3 4 5 1 8 0]
# Candidate solution:   [0 7 3 2 5 9 4 6 8 1]
# Candidate solution:   [1 9 6 4 0 2 3 8 5 7]
# Candidate solution:   [6 2 9 4 1 5 0 7 3 8]
# Candidate solution:   [7 9 3 0 8 2 1 4 6 5]
# Candidate solution:   [6 8 2 1 0 4 9 3 5 7]
# Candidate solution:   [4 2 6 0 9 8 7 1 3 5]
# Candidate solution:   [0 6 8 5 9 2 7 3 1 4]
# Candidate solution:   [7 6 5 3 1 8 2 4 9 0]
# Candidate solution:   [9 0 8 6 2 5 7 1 3 4]
# Candidate solution:   [4 7 3 1 6 9 5 0 8 2]
# Candidate solution:   [3 8 2 6 5 9 0 1 4 7]
# Candidate solution:   [0 7 3 8 5 6 4 2 1 9]
# Candidate solution:   [2 3 9 0 5 1 8 6 4 7]
# Candidate solution:   [0 7 5 8 1 4 3 9 2 6]
# Candidate solution:   [5 4 1 0 3 9 7 2 6 8]
# Candidate solution:   [9 3 1 7 4 5 8 2 0 6]
# Candidate solution:   [4 2 9 7 5 3 1 8 6 0]
# Candidate solution:   [9 2 3 7 5 4 8 0 1 6]
# Candidate solution:   [7 8 4 1 5 6 0 3 2 9]
# Candidate solution:   [9 2 7 4 0 5 8 6 3 1]
# Candidate solution:   [4 2 0 1 5 6 8 9 7 3]
# Candidate solution:   [2 1 3 0 6 7 4 9 5 8]
# Candidate solution:   [3 1 7 6 8 0 9 4 5 2]
# Candidate solution:   [2 0 5 8 6 9 1 7 3 4]
# Candidate solution:   [4 6 9 7 1 0 3 2 5 8]
# Candidate solution:   [2 1 5 0 4 6 3 7 8 9]
# Candidate solution:   [1 9 0 5 8 3 6 4 7 2]
# Candidate solution:   [9 2 4 5 6 0 7 3 8 1]
# Candidate solution:   [0 8 1 9 5 7 2 3 4 6]
# Candidate solution:   [0 7 2 5 4 1 6 3 8 9]
# Candidate solution:   [0 3 6 7 5 9 1 4 8 2]
# Candidate solution:   [3 8 1 6 2 7 9 4 5 0]
# Candidate solution:   [9 4 0 7 5 3 1 2 8 6]
# Candidate solution:   [9 8 3 7 6 5 4 1 2 0]
#
# Mean fitness:   2995
# Best fitness:   2277
# ---------------------------------  ITERATION 0 ---------------------------------
# Mean fitness:   2803
# Best fitness:   2302
# ---------------------------------  ITERATION 1 ---------------------------------
# Mean fitness:   2694
# Best fitness:   2280
# ---------------------------------  ITERATION 2 ---------------------------------
# Mean fitness:   2360
# Best fitness:   2200
# ---------------------------------  ITERATION 3 ---------------------------------
# Mean fitness:   2211
# Best fitness:   2184
# ---------------------------------  ITERATION 4 ---------------------------------
# Mean fitness:   2517
# Best fitness:   2331
# ---------------------------------  ITERATION 5 ---------------------------------
# Mean fitness:   2508
# Best fitness:   2317
# ---------------------------------  ITERATION 6 ---------------------------------
# Mean fitness:   2614
# Best fitness:   2292
# ---------------------------------  ITERATION 7 ---------------------------------
# Mean fitness:   2786
# Best fitness:   2675
# ---------------------------------  ITERATION 8 ---------------------------------
# Mean fitness:   2550
# Best fitness:   2522
# ---------------------------------  ITERATION 9 ---------------------------------
# Mean fitness:   2821
# Best fitness:   2646
# ---------------------------------  ITERATION 10 ---------------------------------
# Mean fitness:   2710
# Best fitness:   2389
# ---------------------------------  ITERATION 11 ---------------------------------
# Mean fitness:   2737
# Best fitness:   2641
# ---------------------------------  ITERATION 12 ---------------------------------
# Mean fitness:   2879
# Best fitness:   2795
# ---------------------------------  ITERATION 13 ---------------------------------
# Mean fitness:   2281
# Best fitness:   2281
# ---------------------------------  ITERATION 14 ---------------------------------
# Mean fitness:   2630
# Best fitness:   2630
# ---------------------------------  ITERATION 15 ---------------------------------
# Mean fitness:   2804
# Best fitness:   2723
# ---------------------------------  ITERATION 16 ---------------------------------
# Mean fitness:   2727
# Best fitness:   2602
# ---------------------------------  ITERATION 17 ---------------------------------
# Mean fitness:   2215
# Best fitness:   2159
# ---------------------------------  ITERATION 18 ---------------------------------
# Mean fitness:   2821
# Best fitness:   2567
# ---------------------------------  ITERATION 19 ---------------------------------
# Mean fitness:   2651
# Best fitness:   2651
# ---------------------------------  ITERATION 20 ---------------------------------
# Mean fitness:   2588
# Best fitness:   2402
# ---------------------------------  ITERATION 21 ---------------------------------
# Mean fitness:   2492
# Best fitness:   2492
# ---------------------------------  ITERATION 22 ---------------------------------
# Mean fitness:   2744
# Best fitness:   2560
# ---------------------------------  ITERATION 23 ---------------------------------
# Mean fitness:   2744
# Best fitness:   2556
# ---------------------------------  ITERATION 24 ---------------------------------
# Mean fitness:   2441
# Best fitness:   2336
# ---------------------------------  ITERATION 25 ---------------------------------
# Mean fitness:   2828
# Best fitness:   2705
# ---------------------------------  ITERATION 26 ---------------------------------
# Mean fitness:   2904
# Best fitness:   2902
# ---------------------------------  ITERATION 27 ---------------------------------
# Mean fitness:   2738
# Best fitness:   2698
# ---------------------------------  ITERATION 28 ---------------------------------
# Mean fitness:   2759
# Best fitness:   2643
# ---------------------------------  ITERATION 29 ---------------------------------
# Mean fitness:   2528
# Best fitness:   2528
# ---------------------------------  ITERATION 30 ---------------------------------
# Mean fitness:   2487
# Best fitness:   2487
# ---------------------------------  ITERATION 31 ---------------------------------
# Mean fitness:   2609
# Best fitness:   2609
# ---------------------------------  ITERATION 32 ---------------------------------
# Mean fitness:   2706
# Best fitness:   2584
# ---------------------------------  ITERATION 33 ---------------------------------
# Mean fitness:   2617
# Best fitness:   2566
# ---------------------------------  ITERATION 34 ---------------------------------
# Mean fitness:   2644
# Best fitness:   2600
# ---------------------------------  ITERATION 35 ---------------------------------
# Mean fitness:   2640
# Best fitness:   2470
# ---------------------------------  ITERATION 36 ---------------------------------
# Mean fitness:   2532
# Best fitness:   2532
# ---------------------------------  ITERATION 37 ---------------------------------
# Mean fitness:   2744
# Best fitness:   2578
# ---------------------------------  ITERATION 38 ---------------------------------
# Mean fitness:   2816
# Best fitness:   2484
# ---------------------------------  ITERATION 39 ---------------------------------
# Mean fitness:   2510
# Best fitness:   2191
# ---------------------------------  ITERATION 40 ---------------------------------
# Mean fitness:   2773
# Best fitness:   2390
# ---------------------------------  ITERATION 41 ---------------------------------
# Mean fitness:   2808
# Best fitness:   2688
# ---------------------------------  ITERATION 42 ---------------------------------
# Mean fitness:   2639
# Best fitness:   2259
# ---------------------------------  ITERATION 43 ---------------------------------
# Mean fitness:   2979
# Best fitness:   2891
# ---------------------------------  ITERATION 44 ---------------------------------
# Mean fitness:   2764
# Best fitness:   2672
# ---------------------------------  ITERATION 45 ---------------------------------
# Mean fitness:   2668
# Best fitness:   2310
# ---------------------------------  ITERATION 46 ---------------------------------
# Mean fitness:   2459
# Best fitness:   2302
# ---------------------------------  ITERATION 47 ---------------------------------
# Mean fitness:   2803
# Best fitness:   2781
# ---------------------------------  ITERATION 48 ---------------------------------
# Mean fitness:   2419
# Best fitness:   2419
# ---------------------------------  ITERATION 49 ---------------------------------
# Mean fitness:   2654
# Best fitness:   2654
# ---------------------------------  ITERATION 50 ---------------------------------
# Mean fitness:   2617
# Best fitness:   2617
# ---------------------------------  ITERATION 51 ---------------------------------
# Mean fitness:   2761
# Best fitness:   2639
# ---------------------------------  ITERATION 52 ---------------------------------
# Mean fitness:   2409
# Best fitness:   2409
# ---------------------------------  ITERATION 53 ---------------------------------
# Mean fitness:   2797
# Best fitness:   2506
# ---------------------------------  ITERATION 54 ---------------------------------
# Mean fitness:   2778
# Best fitness:   2506
# ---------------------------------  ITERATION 55 ---------------------------------
# Mean fitness:   2674
# Best fitness:   2506
# ---------------------------------  ITERATION 56 ---------------------------------
# Mean fitness:   2789
# Best fitness:   2695
# ---------------------------------  ITERATION 57 ---------------------------------
# Mean fitness:   2884
# Best fitness:   2863
# ---------------------------------  ITERATION 58 ---------------------------------
# Mean fitness:   2687
# Best fitness:   2665
# ---------------------------------  ITERATION 59 ---------------------------------
# Mean fitness:   2793
# Best fitness:   2793
# ---------------------------------  ITERATION 60 ---------------------------------
# Mean fitness:   2793
# Best fitness:   2793
# ---------------------------------  ITERATION 61 ---------------------------------
# Mean fitness:   2843
# Best fitness:   2772
# ---------------------------------  ITERATION 62 ---------------------------------
# Mean fitness:   2376
# Best fitness:   2376
# ---------------------------------  ITERATION 63 ---------------------------------
# Mean fitness:   2516
# Best fitness:   2516
# ---------------------------------  ITERATION 64 ---------------------------------
# Mean fitness:   2787
# Best fitness:   2613
# ---------------------------------  ITERATION 65 ---------------------------------
# Mean fitness:   2535
# Best fitness:   2535
# ---------------------------------  ITERATION 66 ---------------------------------
# Mean fitness:   2745
# Best fitness:   2745
# ---------------------------------  ITERATION 67 ---------------------------------
# Mean fitness:   2552
# Best fitness:   2552
# ---------------------------------  ITERATION 68 ---------------------------------
# Mean fitness:   2582
# Best fitness:   2582
# ---------------------------------  ITERATION 69 ---------------------------------
# Mean fitness:   2426
# Best fitness:   2426
# ---------------------------------  ITERATION 70 ---------------------------------
# Mean fitness:   2586
# Best fitness:   2534
# ---------------------------------  ITERATION 71 ---------------------------------
# Mean fitness:   2602
# Best fitness:   2602
# ---------------------------------  ITERATION 72 ---------------------------------
# Mean fitness:   2513
# Best fitness:   2513
# ---------------------------------  ITERATION 73 ---------------------------------
# Mean fitness:   2695
# Best fitness:   2682
# ---------------------------------  ITERATION 74 ---------------------------------
# Mean fitness:   2826
# Best fitness:   2790
# ---------------------------------  ITERATION 75 ---------------------------------
# Mean fitness:   2687
# Best fitness:   2593
# ---------------------------------  ITERATION 76 ---------------------------------
# Mean fitness:   2854
# Best fitness:   2843
# ---------------------------------  ITERATION 77 ---------------------------------
# Mean fitness:   2841
# Best fitness:   2719
# ---------------------------------  ITERATION 78 ---------------------------------
# Mean fitness:   2431
# Best fitness:   2431
# ---------------------------------  ITERATION 79 ---------------------------------
# Mean fitness:   2400
# Best fitness:   2332
# ---------------------------------  ITERATION 80 ---------------------------------
# Mean fitness:   2798
# Best fitness:   2648
# ---------------------------------  ITERATION 81 ---------------------------------
# Mean fitness:   2059
# Best fitness:   2059
# ---------------------------------  ITERATION 82 ---------------------------------
# Mean fitness:   2629
# Best fitness:   2582
# ---------------------------------  ITERATION 83 ---------------------------------
# Mean fitness:   2583
# Best fitness:   2583
# ---------------------------------  ITERATION 84 ---------------------------------
# Mean fitness:   2512
# Best fitness:   2405
# ---------------------------------  ITERATION 85 ---------------------------------
# Mean fitness:   2765
# Best fitness:   2765
# ---------------------------------  ITERATION 86 ---------------------------------
# Mean fitness:   2686
# Best fitness:   2686
# ---------------------------------  ITERATION 87 ---------------------------------
# Mean fitness:   2797
# Best fitness:   2782
# ---------------------------------  ITERATION 88 ---------------------------------
# Mean fitness:   2535
# Best fitness:   2535
# ---------------------------------  ITERATION 89 ---------------------------------
# Mean fitness:   2510
# Best fitness:   2510
# ---------------------------------  ITERATION 90 ---------------------------------
# Mean fitness:   2627
# Best fitness:   2587
# ---------------------------------  ITERATION 91 ---------------------------------
# Mean fitness:   2613
# Best fitness:   2613
# ---------------------------------  ITERATION 92 ---------------------------------
# Mean fitness:   2567
# Best fitness:   2567
# ---------------------------------  ITERATION 93 ---------------------------------
# Mean fitness:   2535
# Best fitness:   2392
# ---------------------------------  ITERATION 94 ---------------------------------
# Mean fitness:   2675
# Best fitness:   2675
# ---------------------------------  ITERATION 95 ---------------------------------
# Mean fitness:   2693
# Best fitness:   2687
# ---------------------------------  ITERATION 96 ---------------------------------
# Mean fitness:   2640
# Best fitness:   2640
# ---------------------------------  ITERATION 97 ---------------------------------
# Mean fitness:   2491
# Best fitness:   2491
# ---------------------------------  ITERATION 98 ---------------------------------
# Mean fitness:   2567
# Best fitness:   2564
# ---------------------------------  ITERATION 99 ---------------------------------
# Mean fitness:   2643
# Best fitness:   2643
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# Candidate solution:   [4 6 3 1 5 8 9 0 2 7]
# Candidate mutation probability:   0.1
# 'best = elimination(pop, pop, tsp)\nfor i in best:\n  print("Candidate solution:  ", i.order)\n  print("Objective value: ", fitness(tsp, i))\n\nfitnesses = [fitness(tsp, ind) for ind in best]\nprint("\nMean fitness:  ", statistics.mean(fitnesses))\nprint("Best fitness:  ", min(fitnesses))\n'

# %%
#a = np.random.randint(1, 10, size=(4, 4))
# np.fill_diagonal(a, 0)
a = np.array([5,1,2,3,4,6])
parent1 = np.array([1,2,3,5,4,7,6])
parent2 = np.array([1,2,3,5,4,6,7])
parent3 = np.array([5,1,2,0,3,4])
parent4 = np.array([1,2,5,3,4,0])
parent5 = np.array([5,1,2,6,3,4])
parent6 = np.array([5,2,1,3,6,4])
print(f'Parent1: {parent1} Parent2: {parent2}')
print(f'Parent3: {parent3} Parent4: {parent4}')
print(f'Parent5: {parent5} Parent6: {parent6}')

def matched_subseq(parent1, parent2):
  # Mejor ponerlos aleatoriamente para mas exploracion en vez de concat
  # CAREFUL [1,2,3,4] = [2,3,4,1]
  matchedSubseq = np.array([], dtype=int)
  window_size = 2
  window_pos = 0
  while window_pos < parent1.size:  
    # extract subsequence from parent
    subseq = parent1[window_pos:window_pos+window_size] #problem: last node is alone
    #print(subseq)
    # Search longest common subsequences
    matched = None
    num_matches = 0
    keepSearching = True
    while (keepSearching and window_pos+window_size <= parent1.size):
      # take the first individual again
      if search_sequence(parent2, subseq):
        # Save matching subsequence
        matched = subseq
        #print(f'Matched: {matched}')
        # If it is the last common subsequence we append it
        if window_pos+window_size is parent1.size: 
          matchedSubseq = np.concatenate((matchedSubseq, matched), axis=None)
          #print('appended subsequence:  ', matched)
        # Increase subsequence length
        num_matches += 1
        window_size += 1
        subseq = parent1[window_pos:window_pos+window_size]
        #print(f'{subseq} from {window_pos} to {window_pos+window_size}')
      else: 
        if matched is not None:
          matchedSubseq = np.concatenate((matchedSubseq, matched), axis=None)
        #print('appended subsequence:  ', matched)
        matched = None
        window_size = 2
        keepSearching = False
    window_pos += 1 + num_matches
  return matchedSubseq
print(f'Appended sequences: {matched_subseq(parent1, parent2)}')
print(f'Appended sequences: {matched_subseq(parent3, parent4)}')
print(f'Appended sequences: {matched_subseq(parent5, parent6)}')

sharedCycles = matched_subseq(parent3, parent4)
order = sharedCycles
node = 0
while (node < parent3.size):
  if not search_sequence(np.array([node]), sharedCycles):
    if np.random.rand() < 0.5:
      order = np.concatenate((order, np.array(node)), axis=None)
    else:
      order = np.concatenate((np.array(node), order), axis=None)
  node += 1
order
# Out:
# Parent1: [1 2 3 5 4 7 6] Parent2: [1 2 3 5 4 6 7]
# Parent3: [5 1 2 0 3 4] Parent4: [1 2 5 3 4 0]
# Parent5: [5 1 2 6 3 4] Parent6: [5 2 1 3 6 4]
# Appended sequences: [1 2 3 5 4]
# Appended sequences: [1 2 3 4]
# Appended sequences: []
# array([1, 2, 3, 4, 0, 5])

# %%
a = np.array([5,1,2,3,4,6])
parent1 = np.array([1,2,3,5,4,7,6])
parent2 = np.array([1,2,3,5,4,6,7])
parent3 = np.array([5,1,2,6,3,4])
parent4 = np.array([1,2,5,3,4,6])
parent5 = np.array([5,1,2,6,3,4])
parent6 = np.array([5,1,2,3,6,4])
print(f'Parent1: {parent1} Parent2: {parent2}')
print(f'Parent3: {parent3} Parent4: {parent4}')
print(f'Parent5: {parent5} Parent6: {parent6}')

def matched_subseq(parent1, parent2):
  matchedSubseq = []
  window_size = 2
  window_pos = 0
  if parent1[0] == parent2[0] and parent1[-1] == parent2[-1]:
    parent1 = np.concatenate((parent1, parent1), axis=None)
    parent2 = np.concatenate((parent2, parent2), axis=None)
  while window_pos < parent1.size:  
    # extract subsequence from parent
    subseq = parent1[window_pos:window_pos+window_size] #problem: last node is alone
    #print(subseq)
    # Search longest common subsequences
    matched = None
    num_matches = 0
    keepSearching = True
    while (keepSearching and window_pos+window_size <= parent1.size):
      # take the first individual again
      if search_sequence(parent2, subseq):
        # Save matching subsequence
        matched = subseq
        #print(f'Matched: {matched}')
        # If it is the last common subsequence we append it
        if window_pos+window_size is parent1.size: 
          matchedSubseq.append(matched)
          #print('appended subsequence:  ', matched)
        # Increase subsequence length
        num_matches += 1
        window_size += 1
        subseq = parent1[window_pos:window_pos+window_size]
        #print(f'{subseq} from {window_pos} to {window_pos+window_size}')
      else: 
        if matched is not None:
          matchedSubseq.append(matched)
        #print('appended subsequence:  ', matched)
        matched = None
        window_size = 2
        keepSearching = False
    window_pos += 1 + num_matches
  return matchedSubseq
print(f'Appended sequences: {matched_subseq(parent1, parent2)}')
print(f'Appended sequences: {matched_subseq(parent3, parent4)}')
print(f'Appended sequences: {matched_subseq(parent5, parent6)}')
#parent5[(4+2)%parent5.size]
problemita = matched_subseq(parent5, parent6)
search_sequence(problemita[0], problemita[1]) 
"""for i in range(len(sharedCycles)):
  if i+1 < len(sharedCycles):
    order = np.concatenate((sharedCycles[i], sharedCycles[i+1]), axis=None)
  i += 1
print(order)"""
# Out:
# Parent1: [1 2 3 5 4 7 6] Parent2: [1 2 3 5 4 6 7]
# Parent3: [5 1 2 6 3 4] Parent4: [1 2 5 3 4 6]
# Parent5: [5 1 2 6 3 4] Parent6: [5 1 2 3 6 4]
# Appended sequences: [array([1, 2, 3, 5, 4])]
# Appended sequences: [array([1, 2]), array([3, 4])]
# Appended sequences: [array([5, 1, 2]), array([4, 5, 1, 2])]
# True
